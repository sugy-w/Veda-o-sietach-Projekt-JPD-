# %%
# imports
import pandas as pd
import numpy as np
import networkx as nx
import random

import seaborn as sns
import matplotlib.pyplot as plt

# %%
edges = pd.read_csv("../data/edges.csv")[["# source", " target", " distance"]].drop_duplicates()

nodes = pd.read_csv("../data/nodes.csv")[[" id", " name", " city", " country"]]
nodes[" id"] = np.arange(0, 3214)

# %% [markdown]
# **Zero distance edge**

# %%
(edges[" distance"] == 0).sum()
# Out:
# np.int64(1)

# %%
id_to_name = dict(zip(nodes[" id"].astype(int), nodes[" name"]))

zero_distance_edges = edges[edges[" distance"] == 0].copy()

zero_distance_edges["source_name"] = zero_distance_edges["# source"].map(id_to_name)
zero_distance_edges["target_name"] = zero_distance_edges[" target"].map(id_to_name)

print(zero_distance_edges)
# Out:
#        # source   target   distance       source_name       target_name
# 57361      1931     1931        0.0  Iskandar Airport  Iskandar Airport

# %%
source_airport = np.array(edges["# source"])
destination_airport = np.array(edges[" target"])

# %% [markdown]
# **Graph keeping zero distance edge**

# %%
G = nx.from_pandas_edgelist(
    edges,
    source="# source",
    target=" target",
    edge_attr=" distance",
    create_using=nx.DiGraph()
)

# %% [markdown]
# **Graph removing zero distance edge**

# %%
A = np.zeros((3214, 3214))

for source, target, distance in edges.values:
    A[int(source)][int(target)] = distance

G = nx.from_numpy_array(A, create_using=nx.DiGraph) # directed graph

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (3214, 36906)

# %% [markdown]
# **Asortativity**

# %% [markdown]
# V sieti neexistuje výrazná tendencia, aby sa letiská pripájali k letiskám s podobným alebo odlišným počtom spojení.

# %%
r = nx.degree_assortativity_coefficient(G)
print(f"Degree assortativity coefficient: {r:.4f}") # approx. 0
# Out:
# Degree assortativity coefficient: -0.0192

# %% [markdown]
# **Density**

# %% [markdown]
# - existuje iba ~0.36 % všetkých možných spojení

# %%
density = nx.density(G)
print(f"Density: {density:.6f}")
# Out:
# Density: 0.003574

# %% [markdown]
# **Reciprocita**

# %% [markdown]
# - skoro všetky letecké spojenia sú obojsmerné, sieť je skoro úplne symetrická

# %%
reciprocity = nx.reciprocity(G)
print(f"Reciprocity: {reciprocity:.4f}")
# Out:
# Reciprocity: 0.9781

# %% [markdown]
# **Articulations**

# %%
# Bridges and articulation points require undirected graphs
G_undirected = G.to_undirected()

# %%
articulation_points = list(nx.articulation_points(G_undirected))
print(f"Number of articulation points: {len(articulation_points)}")
# Out:
# Number of articulation points: 333
# [34, 113, 2287, 2330, 2292, 57, 156, 216, 254, 261]

# %%
def match_id(array, nodes_df, top_n=333):
    id_to_name = dict(zip(nodes_df[" id"].astype(int), nodes_df[" name"]))
    centrality_list = [(int(i), id_to_name.get(int(i), "Unknown")) for i in array]
    centrality_list_sorted = sorted(centrality_list, key=lambda x: x[1], reverse=True)
    for i, (nid, name) in enumerate(centrality_list_sorted[:top_n], 1):
        print(f"{i}. {name} (id={nid})")

# %%
match_id(articulation_points, nodes)
# Out:
# 1. Ürümqi Diwopu International Airport (id=1675)
# 2. Zamboanga International Airport (id=1120)
# 3. Zagreb Airport (id=564)
# 4. Yuzhno-Sakhalinsk Airport (id=1395)
# 285. Christmas Island Airport (id=1634)
# 286. Christchurch International Airport (id=941)
# 287. Chinggis Khaan International Airport (id=1656)
# 288. Chicago O'Hare International Airport (id=1885)
# 289. Chicago Midway International Airport (id=1850)
# 290. Chiang Mai International Airport (id=1944)
# 291. Chhatrapati Shivaji International Airport (id=1445)
# 292. Cheyenne Regional Jerry Olson Field (id=1871)
# 293. Cherepovets Airport (id=2633)
# 294. Chengdu Shuangliu International Airport (id=1671)
# 295. Charlotte Douglas International Airport (id=1913)
# 296. Charles de Gaulle International Airport (id=628)
# 297. Cardiff International Airport (id=244)
# 298. Campo Grande Airport (id=1173)
# 299. Calgary International Airport (id=113)
# 300. Cairns International Airport (id=1612)
# 301. Bukavu Kavumu Airport (id=467)
# 302. Brussels Airport (id=184)
# 303. Brisbane International Airport (id=1610)
# 304. Boryspil International Airport (id=1401)
# 305. Boeing Field King County International Airport (id=1837)
# 306. Bodø Airport (id=307)
# 307. Billings Logan International Airport (id=2008)
# 308. Bethel Airport (id=1765)
# 309. Berlin-Tegel Airport (id=201)
# 310. Bergen Airport Flesland (id=308)
# 311. Benazir Bhutto International Airport (id=1034)
# 312. Ben Gurion International Airport (id=718)
# 313. Beijing Nanyuan Airport (id=2767)
# 314. Bayankhongor Airport (id=2794)
# 315. Bauerfield International Airport (id=930)
# 316. Bateen Airport (id=1016)
# 317. Barcelona International Airport (id=570)
# 318. Bandaranaike International Colombo Airport (id=1463)
# 319. Baita International Airport (id=2771)
# 320. Auckland International Airport (id=939)
# 321. Attawapiskat Airport (id=2287)
# 322. Atatürk International Airport (id=770)
# 323. Aswan International Airport (id=526)
# 324. Asmara International Airport (id=1968)
# 325. Aniak Airport (id=2567)
# 326. Alfredo Vásquez Cobo International Airport (id=1279)
# 327. Alfonso Bonilla Aragon International Airport (id=1270)
# 328. Albuquerque International Sunport (id=2006)
# 329. Albany International Airport (id=1907)
# 330. Afonso Pena Airport (id=1178)
# 331. Adolfo Suárez Madrid–Barajas Airport (id=578)
# 332. Adelaide International Airport (id=1627)
# 333. Addis Ababa Bole International Airport (id=508)

# %% [markdown]
# **Bridges**

# %%
bridges = list(nx.bridges(G_undirected))
print(f"Number of bridges: {len(bridges)}")
# Out:
# Number of bridges: 757

# %%
id_to_name = dict(zip(
    nodes[" id"].astype(int),
    nodes[" name"]
))

# %%
def map_bridges(bridge_list, id_to_name, top_n=None):
    mapped = []
    for u, v in bridge_list:
        mapped.append((int(u),id_to_name.get(int(u), "Unknown"),int(v),id_to_name.get(int(v), "Unknown")))

    mapped_sorted = sorted(mapped, key=lambda x: x[1])

    if top_n:
        mapped_sorted = mapped_sorted[:top_n]

    for i, (u_id, u_name, v_id, v_name) in enumerate(mapped_sorted, 1):
        print(f"{i}. " f"{u_name} (id={u_id}) "f"<--> "f"{v_name} (id={v_id})")

# %%
map_bridges(bridges, id_to_name, top_n=10)
# Out:
# 1. Abu Simbel Airport (id=522) <--> Aswan International Airport (id=526)
# 2. Addis Ababa Bole International Airport (id=508) <--> Mekele Airport (id=517)
# 3. Adelaide International Airport (id=1627) <--> Kingscote Airport (id=2034)
# 4. Adelaide International Airport (id=1627) <--> Coober Pedy Airport (id=2714)
# 5. Adelaide International Airport (id=1627) <--> Ceduna Airport (id=2716)
# 6. Adelaide International Airport (id=1627) <--> Olympic Dam Airport (id=2749)
# 7. Adelaide International Airport (id=1627) <--> Port Augusta Airport (id=2750)
# 8. Adelaide International Airport (id=1627) <--> Port Lincoln Airport (id=2755)
# 9. Adelaide International Airport (id=1627) <--> Whyalla Airport (id=2764)
# 10. Adolfo Suárez Madrid–Barajas Airport (id=578) <--> Pamplona Airport (id=581)

# %% [markdown]
# **Articulation Removal**

# %%
def articulation_impact(G, articulation_points):
    original_components = nx.number_connected_components(G)
    impacts = []

    for node in articulation_points:

        G_temp = G.copy()
        G_temp.remove_node(node)

        new_components = nx.number_connected_components(G_temp)
        impacts.append((node, new_components - original_components))

    return sorted(impacts, key=lambda x: x[1], reverse=True)

# %%
impacts = articulation_impact(G_undirected,articulation_points)

# %% [markdown]
# **Impact**

# %%
# how much components increase when we remove the articulation point?

# %%
for node_id, impact in impacts[:20]:

    airport_name = id_to_name.get(node_id, "Unknown")

    print(
        f"{airport_name} "
        f"(id={node_id}) "
        f"-> impact: {impact}"
    )
# Out:
# El Dorado International Airport (id=1264) -> impact: 18
# Denver International Airport (id=1853) -> impact: 15
# Tokyo Haneda International Airport (id=1102) -> impact: 14
# Jorge Newbery Airpark (id=1132) -> impact: 13
# Ninoy Aquino International Airport (id=1115) -> impact: 13
# Ted Stevens Anchorage International Airport (id=1861) -> impact: 12
# Don Mueang International Airport (id=1526) -> impact: 12
# Dallas Fort Worth International Airport (id=1800) -> impact: 11
# Hartsfield Jackson Atlanta International Airport (id=1809) -> impact: 10
# Jorge Chávez International Airport (id=1317) -> impact: 10
# Licenciado Benito Juarez International Airport (id=832) -> impact: 10
# Domodedovo International Airport (id=2016) -> impact: 10
# Helsinki Vantaa Airport (id=218) -> impact: 10
# Simón Bolívar International Airport (id=1340) -> impact: 9
# Sydney Kingsford Smith International Airport (id=1639) -> impact: 9
# Tribhuvan International Airport (id=1509) -> impact: 8
# Perth International Airport (id=1633) -> impact: 8
# Bethel Airport (id=1765) -> impact: 8
# Mehrabad International Airport (id=1000) -> impact: 8
# Chicago O'Hare International Airport (id=1885) -> impact: 8

# %% [markdown]
# **El Dorado Airport**

# %%
node_to_remove = 1264

G_temp = G_undirected.copy()

G_temp.remove_node(node_to_remove)

components = list(nx.connected_components(G_temp))

print(f"Number of components after removing {node_to_remove}: {len(components)}")
# Out:
# Number of components after removing 1264: 25

# %%
for i, component in enumerate(sorted(components, key=len, reverse=True),1):
    component_sorted = sorted(component)
    print(f"\nComponent {i} "f"(size={len(component_sorted)})")
# Out:
# Component 1 (size=3163)
#
# Component 2 (size=10)
#
# Component 3 (size=4)
#
# Component 4 (size=4)
#
# Component 5 (size=4)
#
# Component 6 (size=4)
#
# Component 7 (size=2)
#
# Component 8 (size=2)
#
# Component 9 (size=2)
#
# Component 10 (size=2)
#
# Component 11 (size=2)
#
# Component 12 (size=1)
#
# Component 13 (size=1)
#
# Component 14 (size=1)
#
# Component 15 (size=1)
#
# Component 16 (size=1)
#
# Component 17 (size=1)
#
# Component 18 (size=1)
#
# Component 19 (size=1)
#
# Component 20 (size=1)
#
# Component 21 (size=1)
#
# Component 22 (size=1)
#
# Component 23 (size=1)
#
# Component 24 (size=1)
#
# Component 25 (size=1)

# %% [markdown]
# **Top airports with the highest degree**

# %%
top_degree = sorted(G_undirected.degree,key=lambda x: x[1],reverse=True)[:5]

for node, degree in top_degree:
    print(id_to_name[node], degree)
# Out:
# Amsterdam Airport Schiphol 248
# Frankfurt am Main Airport 244
# Charles de Gaulle International Airport 240
# Atatürk International Airport 233
# Hartsfield Jackson Atlanta International Airport 217

# %% [markdown]
# #### **Correlation**

# %%
articulation_points = set(nx.articulation_points(G_undirected))
degrees = dict(G_undirected.degree())

rows = []

for node in G_undirected.nodes():

    rows.append({
        "node_id": node,
        "airport_name": id_to_name.get(node, "Unknown"),
        "degree": degrees[node],
        "is_articulation": int(node in articulation_points)
    })

df = pd.DataFrame(rows)

correlation = df["degree"].corr(df["is_articulation"])

print("\n=== CORRELATION ===\n")
print(f"Correlation between degree and articulation status: {correlation:.4f}")


mean_art = df[df["is_articulation"] == 1]["degree"].mean()
mean_non = df[df["is_articulation"] == 0]["degree"].mean()

print("\n=== MEAN DEGREE ===\n")
print(f"Articulation points mean degree: {mean_art:.2f}")
print(f"Non-articulation nodes mean degree: {mean_non:.2f}")

print("\n=== TOP ARTICULATION POINTS BY DEGREE ===\n")

top_articulations = (df[df["is_articulation"] == 1].sort_values("degree", ascending=False))
print(top_articulations[["node_id", "airport_name", "degree"]].head(20))

plt.figure(figsize=(10,6))

plt.scatter(df["degree"],df["is_articulation"],alpha=0.5)

plt.xlabel("Degree")
plt.ylabel("Is articulation point")
plt.title("Degree vs Articulation Status")
plt.show()


plt.figure(figsize=(10,6))

plt.hist(df[df["is_articulation"] == 1]["degree"],bins=30,alpha=0.7,label="Articulation points")

plt.hist(df[df["is_articulation"] == 0]["degree"],bins=30,alpha=0.7,label="Non-articulation nodes")

plt.xlabel("Degree")
plt.ylabel("Count")
plt.xscale("log")
plt.yscale("log")
plt.title("Degree Distribution Comparison")

plt.legend()
plt.show()
# Out:
# === CORRELATION ===
#
# Correlation between degree and articulation status: 0.3790
#
# === MEAN DEGREE ===
#
# Articulation points mean degree: 39.64
# Non-articulation nodes mean degree: 8.51
#
# === TOP ARTICULATION POINTS BY DEGREE ===
#
#       node_id                                      airport_name  degree
# 628       628           Charles de Gaulle International Airport     240
# 770       770                     Atatürk International Airport     233
# 1809     1809  Hartsfield Jackson Atlanta International Airport     217
# 1885     1885              Chicago O'Hare International Airport     206
# 1800     1800           Dallas Fort Worth International Airport     188
# 2016     2016                  Domodedovo International Airport     188
# 1017     1017                       Dubai International Airport     185
# 1853     1853                      Denver International Airport     169
# 1744     1744      George Bush Intercontinental Houston Airport     169
# 570       570                   Barcelona International Airport     163
# 706       706               Leonardo da Vinci–Fiumicino Airport     162
# 578       578              Adolfo Suárez Madrid–Barajas Airport     159
# 279       279                           London Stansted Airport     153
# 184       184                                  Brussels Airport     153
# 1679     1679             Shanghai Pudong International Airport     152
# 1715     1715                 Los Angeles International Airport     148
# 125       125           Lester B. Pearson International Airport     147
# 1435     1435                Sheremetyevo International Airport     144
# 1913     1913           Charlotte Douglas International Airport     141
# 1753     1753                       Miami International Airport     138

# %%
average_degree = sum(dict(G.degree()).values()) / G.number_of_nodes()
print(average_degree)
# Out:
# 22.965774735532047

# %% [markdown]
# **Betweenness vs. Articulation**

# %%
betweenness = nx.betweenness_centrality(G_undirected)
articulation_set = set(nx.articulation_points(G_undirected))

df = pd.DataFrame({"node": list(G_undirected.nodes()),
        "betweenness": [
        betweenness[node]
        for node in G_undirected.nodes()
    ],
    "is_articulation": [
        1 if node in articulation_set else 0
        for node in G_undirected.nodes()
    ]
})

correlation = df["betweenness"].corr(df["is_articulation"])
print(f"Correlation between betweenness and articulation status: "f"{correlation:.4f}")
# Out:
# Correlation between betweenness and articulation status: 0.4187

# %%
df.groupby("is_articulation")["betweenness"].mean()
# Out:
# is_articulation
# 0    0.000299
# 1    0.006159
# Name: betweenness, dtype: float64

# %% [markdown]
# **Impact vs. Degree**

# %%
articulations = list(nx.articulation_points(G_undirected))
data = []

for node in articulations:
    degree = G_undirected.degree[node]

    G_temp = G_undirected.copy()
    original_components = nx.number_connected_components(G_temp)

    G_temp.remove_node(node)
    new_components = nx.number_connected_components(G_temp)

    impact = new_components - original_components

    data.append({
        "node": node,
        "degree": degree,
        "impact": impact
    })

df_impact = pd.DataFrame(data)
correlation = df_impact["degree"].corr(df_impact["impact"])

print(f"Correlation between articulation impact and degree: "f"{correlation:.4f}")
# Out:
# Correlation between articulation impact and degree: 0.3312

# %% [markdown]
# #### **Sequential removal**

# %%
def sequential_removal_analysis(G, strategy="highest_degree", seed=42):
    """
    Strategies:
    - "random"
    - "highest_degree"
    - "dynamic_highest_degree"
    - "articulation"
    - "dynamic_articulation"
    - "betweenness"
    - "dynamic_betweenness"
    """

    random.seed(seed)

    G_temp = G.copy()
    original_n = G.number_of_nodes()
    original_size = len(max(nx.connected_components(G_temp), key=len))

    removed_fraction = []
    giant_component_fraction = []
    number_of_components = []
    removed_nodes = []

    if strategy == "random":
        removal_order = list(G_temp.nodes())
        random.shuffle(removal_order)

    elif strategy == "highest_degree":
        removal_order = [
            node for node, degree in sorted(
                G_temp.degree,
                key=lambda x: x[1],
                reverse=True
            )
        ]

    elif strategy == "articulation":
        articulations = list(nx.articulation_points(G_temp))

        non_articulations = [
            node for node in G_temp.nodes()
            if node not in articulations
        ]

        removal_order = articulations + non_articulations

    elif strategy == "betweenness":
        betweenness = nx.betweenness_centrality(G_temp)

        removal_order = [
            node for node, value in sorted(
                betweenness.items(),
                key=lambda x: x[1],
                reverse=True
            )
        ]

    elif strategy in ["dynamic_highest_degree","dynamic_articulation","dynamic_betweenness"]:
        removal_order = None

    else:
        raise ValueError(
            "Unknown strategy. Use: random, highest_degree, "
            "dynamic_highest_degree, articulation, dynamic_articulation, "
            "betweenness, dynamic_betweenness"
        )

    while G_temp.number_of_nodes() > 0:

        if strategy == "dynamic_highest_degree":
            node_to_remove = max(G_temp.nodes(),key=lambda node: G_temp.degree[node])

        elif strategy == "dynamic_articulation":
            articulations = list(nx.articulation_points(G_temp))

            if len(articulations) > 0:
                node_to_remove = max(articulations,key=lambda node: G_temp.degree[node])
            else:
                node_to_remove = max(G_temp.nodes(),key=lambda node: G_temp.degree[node])

        elif strategy == "dynamic_betweenness":
            betweenness = nx.betweenness_centrality(G_temp)

            node_to_remove = max(betweenness,key=betweenness.get)

        else:
            node_to_remove = removal_order[len(removed_nodes)]

        G_temp.remove_node(node_to_remove)
        removed_nodes.append(node_to_remove)

        if G_temp.number_of_nodes() > 0:
            largest_cc = max(nx.connected_components(G_temp), key=len)
            giant_size = len(largest_cc)
            components_count = nx.number_connected_components(G_temp)
        else:
            giant_size = 0
            components_count = 0

        removed_fraction.append(len(removed_nodes) / original_n)
        giant_component_fraction.append(giant_size / original_size)
        number_of_components.append(components_count)

    return removed_fraction, giant_component_fraction, number_of_components, removed_nodes

# %%
strategies = [
    "random",
    "highest_degree",
    "dynamic_highest_degree",
    "dynamic_articulation",
    "betweenness",
    "dynamic_betweenness"
]

# %%
results = {}

for strategy in strategies:
    print("Running:", strategy)

    results[strategy] = sequential_removal_analysis(G_undirected, strategy=strategy)
# Out:
# Running: random
# Running: highest_degree
# Running: dynamic_highest_degree
# Running: dynamic_articulation
# Running: betweenness
# Running: dynamic_betweenness

# %% [markdown]
# **Network Robustness Under Node Removal**

# %%
plt.figure(figsize=(10,6))

colors = {
    "random": "#FFB703",
    "highest_degree": "#FB8500",
    "dynamic_highest_degree": "#023047",
    "dynamic_articulation": "#219EBC",
    "betweenness": "#FC66D7",
    "dynamic_betweenness": "#FF0000"
}

for strategy in strategies:
    x, y, components, removed = results[strategy]
    plt.plot(x, y, label=strategy, color = colors.get(strategy, None))

plt.xlabel("Fraction of removed airports")
plt.ylabel("Relative giant component size")
plt.title("Network Robustness Under Node Removal")
plt.legend()
#plt.yscale("log")
plt.grid(False)
plt.show()

# %% [markdown]
# **Network Fragmentation Under Node Removal**

# %%
plt.figure(figsize=(10,6))

for strategy in strategies:
    x, y, components, removed = results[strategy]
    plt.plot(x, components, label=strategy, color = colors.get(strategy, None))

plt.xlabel("Fraction of removed airports")
plt.ylabel("Number of connected components")
plt.title("Network Fragmentation Under Node Removal")
plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# **Difference**

# %%
(np.array(results["dynamic_highest_degree"][1]) - np.array(results["dynamic_articulation"][1])).mean() * 100
# Out:
# np.float64(0.6545332957520384)

# %%
x_deg, y_deg, c_deg, r_deg = results["dynamic_highest_degree"]
x_art, y_art, c_art, r_art = results["dynamic_articulation"]
x_bet, y_bet, c_bet, r_bet = results["betweenness"]
x_dbet, y_dbet, c_dbet, r_dbet = results["dynamic_betweenness"]

# convert to numpy arrays
y_deg = np.array(y_deg)
y_art = np.array(y_art)
y_bet = np.array(y_bet)
y_dbet = np.array(y_dbet)

# percentage changes
pct_deg = (
    (y_deg[1:] - y_deg[:-1])
    / y_deg[:-1]
) * 100

pct_art = (
    (y_art[1:] - y_art[:-1])
    / y_art[:-1]
) * 100
pct_bet = (
    (y_bet[1:] - y_bet[:-1])
    / y_bet[:-1]
) * 100
pct_dbet = (
    (y_dbet[1:] - y_dbet[:-1])
    / y_dbet[:-1]
) * 100

# %% [markdown]
# **Area Under the Curve**

# %%
auc_results = {}

for strategy in strategies:
    x, y, components, removed = results[strategy]
    auc = np.trapezoid(y, x)
    auc_results[strategy] = auc

auc_df = pd.DataFrame(list(auc_results.items()),columns=["strategy", "auc"])
auc_df = auc_df.sort_values("auc")

print(auc_df)
# Out:
#                  strategy       auc
# 5     dynamic_betweenness  0.035947
# 3    dynamic_articulation  0.072243
# 4             betweenness  0.076796
# 1          highest_degree  0.078769
# 2  dynamic_highest_degree  0.078788
# 0                  random  0.387399

# %%
random_auc = auc_results["random"]

auc_df["relative_to_random"] = (auc_df["auc"] / random_auc)
auc_df["loss_compared_to_random_%"] = ((1 - auc_df["auc"] / random_auc) * 100)

print(auc_df)
# Out:
#                  strategy       auc  relative_to_random  \
# 5     dynamic_betweenness  0.035947            0.092792
# 3    dynamic_articulation  0.072243            0.186481
# 4             betweenness  0.076796            0.198236
# 1          highest_degree  0.078769            0.203329
# 2  dynamic_highest_degree  0.078788            0.203377
# 0                  random  0.387399            1.000000
#
#    loss_compared_to_random_%
# 5                  90.720835
# 3                  81.351882
# 4                  80.176433
# 1                  79.667122
# 2                  79.662335
# 0                   0.000000

# %%
colors = {
    "random": "#FFB703",
    "highest_degree": "#FB8500",
    "dynamic_highest_degree": "#023047",
    "dynamic_articulation": "#219EBC",
    "betweenness": "#FC66D7",
    "dynamic_betweenness": "#FF0000"
}

bar_colors = [
    colors[strategy]
    for strategy in auc_df["strategy"]
]

plt.figure(figsize=(11,6))

bars = plt.bar(
    auc_df["strategy"],
    auc_df["auc"],
    color=bar_colors,
    edgecolor="black",
    linewidth=1.2
)

plt.grid(False)
ax = plt.gca()

for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_linewidth(1.2)

plt.xlabel("Removal strategy", fontsize=12)
plt.ylabel("AUC", fontsize=12)

plt.title("Area Under Robustness Curve by Strategy", fontsize=14,pad=15)
plt.xticks(rotation=30,ha="right")

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 0.005,
        f"{height:.3f}",
        ha="center",
        va="bottom",
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relative percentual drops**

# %%
plt.figure(figsize=(10,6))

plt.plot(
    x_deg[1:],
    pct_deg,
    label="Dynamic highest degree"
)

plt.plot(
    x_art[1:],
    pct_art,
    label="Dynamic articulation"
)
plt.plot(
    x_bet[1:],
    pct_bet,
    label="Betweenness"
)
plt.plot(
    x_dbet[1:],
    pct_dbet,
    label="Dynamic betweenness"
)


plt.axhline(0, linestyle="--")

plt.xlabel("Fraction of removed airports")
plt.ylabel("% change in giant component")

plt.title(
    "Relative Change of Giant Component Size"
)

plt.legend()
plt.grid(False)

plt.show()

# %%
sum(pct_deg) / len(pct_deg), sum(pct_art) / len(pct_art)
# Out:
# (np.float64(-0.2515729523519712), np.float64(-0.25665156398067346))

# %% [markdown]
# #### **Bridges**

# %%
def dynamic_bridge_removal_analysis(G, seed=42):

    random.seed(seed)

    G_temp = G.copy()

    original_n = G.number_of_nodes()
    original_size = len(max(nx.connected_components(G_temp), key=len))

    removed_fraction = []
    giant_component_fraction = []
    number_of_components = []

    removed_edges = []

    while G_temp.number_of_edges() > 0:

        bridges = list(nx.bridges(G_temp))

        if len(bridges) > 0:
            # remove bridge connecting highest degree vertices
            edge_to_remove = max(
                bridges,
                key=lambda edge:
                    G_temp.degree[edge[0]] +
                    G_temp.degree[edge[1]]
            )

        else:
            edge_to_remove = max(
                G_temp.edges(),
                key=lambda edge:
                    G_temp.degree[edge[0]] +
                    G_temp.degree[edge[1]]
            )

        G_temp.remove_edge(*edge_to_remove)
        removed_edges.append(edge_to_remove)


        if G_temp.number_of_nodes() > 0:
            largest_cc = max(nx.connected_components(G_temp),key=len)
            giant_size = len(largest_cc)
            components_count = nx.number_connected_components(G_temp)

        else:
            giant_size = 0
            components_count = 0

        removed_fraction.append(len(removed_edges) / G.number_of_edges())

        giant_component_fraction.append(giant_size / original_size)

        number_of_components.append(components_count)

    return (
        removed_fraction,
        giant_component_fraction,
        number_of_components,
        removed_edges
    )

def random_edge_removal_analysis(G, seed=42):

    random.seed(seed)

    G_temp = G.copy()

    original_size = len(max(nx.connected_components(G_temp), key=len))

    edges = list(G_temp.edges())
    random.shuffle(edges)

    removed_fraction = []
    giant_component_fraction = []
    number_of_components = []

    removed_edges = []

    for edge in edges:

        if G_temp.has_edge(*edge):
            G_temp.remove_edge(*edge)
            removed_edges.append(edge)

            if G_temp.number_of_nodes() > 0:

                largest_cc = max(nx.connected_components(G_temp),key=len)
                giant_size = len(largest_cc)
                components_count = nx.number_connected_components(G_temp)

            else:
                giant_size = 0
                components_count = 0

            removed_fraction.append(len(removed_edges) / G.number_of_edges())

            giant_component_fraction.append(giant_size / original_size)

            number_of_components.append(components_count)

    return (
        removed_fraction,
        giant_component_fraction,
        number_of_components,
        removed_edges
    )

# %%
# run
x_bridge, y_bridge, c_bridge, r_bridge = (dynamic_bridge_removal_analysis(G_undirected))
x_random, y_random, c_random, r_random = (random_edge_removal_analysis(G_undirected))

# %% [markdown]
# **Network Robustness Under Edge Removal**

# %%
# plot giant component
plt.figure(figsize=(10,6))

plt.plot(x_bridge,y_bridge,label="Dynamic bridge removal")
plt.plot(x_random,y_random,label="Random edge removal")

plt.xlabel("Fraction of removed edges")
plt.ylabel("Relative giant component size")
plt.title("Network Robustness Under Edge Removal")

plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# **Network Fragmentation Under Edge Removal**

# %%
# plot connected components
plt.figure(figsize=(10,6))

plt.plot(x_bridge,c_bridge,label="Dynamic bridge removal")
plt.plot(x_random,c_random,label="Random edge removal")

plt.xlabel("Fraction of removed edges")
plt.ylabel("Number of connected components")
plt.title("Network Fragmentation Under Edge Removal")

plt.legend()
plt.grid(False)

plt.show()

# %% [markdown]
# #### Other

# %%
core_numbers = nx.core_number(G_undirected)

core_df = pd.DataFrame({
    "node": list(core_numbers.keys()),
    "airport": [id_to_name.get(n, "Unknown") for n in core_numbers.keys()],
    "core_number": list(core_numbers.values()),
    "degree": [G_undirected.degree[n] for n in core_numbers.keys()]
})

core_df.sort_values("core_number", ascending=False).head(30)
# Out:
#       node                                  airport  core_number  degree
# 1435  1435       Sheremetyevo International Airport           31     144
# 279    279                  London Stansted Airport           31     153
# 245    245                          Bristol Airport           31      73
# 282    282               Amsterdam Airport Schiphol           31     248
# 1017  1017              Dubai International Airport           31     185
# 270    270            Glasgow International Airport           31      63
# 242    242                       Manchester Airport           31     148
# 597    597                 Toulouse-Blagnac Airport           31      47
# 1408  1408                          Pulkovo Airport           31     112
# 271    271                        Edinburgh Airport           31      89
# 1962  1962               Riga International Airport           31      68
# 368    368                Stockholm-Arlanda Airport           31     124
# 476    476                    Fuerteventura Airport           31      55
# 480    480                        Lanzarote Airport           31      57
# 479    479                     Gran Canaria Airport           31      82
# 593    593                Bordeaux-Mérignac Airport           31      49
# 578    578     Adolfo Suárez Madrid–Barajas Airport           31     159
# 579    579                           Málaga Airport           31     117
# 586    586                         Valencia Airport           31      57
# 259    259                   Leeds Bradford Airport           31      51
# 262    262                        Newcastle Airport           31      49
# 570    570          Barcelona International Airport           31     163
# 340    340                    Warsaw Chopin Airport           31      78
# 575    575                            Ibiza Airport           31      59
# 566    566           Alicante International Airport           31      96
# 295    295               Copenhagen Kastrup Airport           31     122
# 3204  3204              Hamad International Airport           31     117
# 302    302  Luxembourg-Findel International Airport           31      56
# 193    193                          Hamburg Airport           31      87
# 184    184                         Brussels Airport           31     153

# %%
node_country = dict(zip(nodes[" id"].astype(int), nodes[" country"]))

country_art = pd.DataFrame({
    "node": list(articulation_points),
    "airport": [id_to_name.get(n, "Unknown") for n in articulation_points],
    "country": [node_country.get(n, "Unknown") for n in articulation_points],
    "degree": [G_undirected.degree[n] for n in articulation_points]
})

country_art["country"].value_counts().head(20)
# Out:
# country
# United States       62
# Brazil              21
# Canada              21
# Australia           17
# Russia              12
# China               10
# Indonesia            9
# Greenland            7
# Colombia             7
# United Kingdom       6
# France               6
# India                5
# Sweden               4
# Congo (Kinshasa)     4
# Spain                4
# Burma                4
# Malaysia             4
# Philippines          3
# Vanuatu              3
# Algeria              3
# Name: count, dtype: int64

# %% [markdown]
# **Top Countries by Number of Airports**

# %%
top_countries = (nodes[" country"].value_counts().head(10))
print(top_countries)
# Out:
#  country
# United States    549
# Canada           206
# China            173
# Brazil           122
# Australia        113
# Russia           103
# India             68
# Indonesia         63
# Japan             62
# Mexico            56
# Name: count, dtype: int64

# %% [markdown]
# **Number of Airports vs. Number of Articulations by Country**

# %%
node_country = dict(zip(nodes[" id"].astype(int), nodes[" country"]))

airports_per_country = (
    nodes[" country"]
    .value_counts()
    .reset_index()
)

airports_per_country.columns = ["country", "num_airports"]

articulation_country_df = pd.DataFrame({
    "node": list(articulation_points),
    "country": [
        node_country.get(node, "Unknown")
        for node in articulation_points
    ]
})

articulations_per_country = (
    articulation_country_df["country"]
    .value_counts()
    .reset_index()
)

articulations_per_country.columns = ["country", "num_articulations"]

# merge
country_df = pd.merge(
    airports_per_country,
    articulations_per_country,
    on="country",
    how="left"
)

country_df["num_articulations"] = (country_df["num_articulations"].fillna(0))

# Correlation
correlation = country_df["num_airports"].corr(country_df["num_articulations"])
print(f"Correlation: {correlation:.4f}")

plt.figure(figsize=(10,6))
plt.scatter(
    country_df["num_airports"],
    country_df["num_articulations"],
    alpha=0.7
)

plt.xlabel("Number of airports")
plt.ylabel("Number of articulation airports")
plt.title("Airports vs Articulation Airports by Country")

plt.grid(False)
plt.show()
# Out:
# Correlation: 0.9673

# %% [markdown]
# **Leaf Airports**

# %%
leaf_airports = []

for node, degree in G_undirected.degree():
    if degree == 1:
        leaf_airports.append({
            "node_id": node,
            "airport_name": id_to_name.get(node, "Unknown"),
            "country": node_country.get(node, "Unknown")
        })

leaf_df = pd.DataFrame(leaf_airports)

print(f"Number of leaf airports: {len(leaf_df)}")
print(leaf_df.head(30))
# Out:
# Number of leaf airports: 718
#     node_id                              airport_name    country
# 0         9                            Thule Air Base  Greenland
# 1        10                          Akureyri Airport    Iceland
# 2        11                       Egilsstaðir Airport    Iceland
# 3        12                        Ísafjörður Airport    Iceland
# 4        21                 Brandon Municipal Airport     Canada
# 5        37                      Fort Simpson Airport     Canada
# 6        38            Kingston Norman Rogers Airport     Canada
# 7        54                      Lloydminster Airport     Canada
# 8        63                     Prince Rupert Airport     Canada
# 9        69                 Lethbridge County Airport     Canada
# 10       88                       Tuktoyaktuk Airport     Canada
# 11       93                      Qikiqtarjuaq Airport     Canada
# 12      103                      Medicine Hat Airport     Canada
# 13      116                         Penticton Airport     Canada
# 14      127                          Sandspit Airport     Canada
# 15      128                    Chris Hadfield Airport     Canada
# 16      131                    Fort Mcpherson Airport     Canada
# 17      138              Cheikh Larbi Tébessi Airport    Algeria
# 18      150              Touggourt Sidi Madhi Airport    Algeria
# 19      157                            Tamale Airport      Ghana
# 20      158                           Sunyani Airport      Ghana
# 21      159                          Takoradi Airport      Ghana
# 22      165                            Ibadan Airport    Nigeria
# 23      166              Ilorin International Airport    Nigeria
# 24      167                      Yakubu Gowon Airport    Nigeria
# 25      168                            Kaduna Airport    Nigeria
# 26      172  Sadiq Abubakar III International Airport    Nigeria
# 27      173                              Yola Airport    Nigeria
# 28      183    Antwerp International Airport (Deurne)    Belgium
# 29      205                     Mannheim-City Airport    Germany

# %% [markdown]
# **How many bridges are leaf related?**

# %% [markdown]
# Large number of non-leaf bridges means:
#
# the network contains vulnerable regional bottlenecks beyond simple peripheral airports.

# %%
leaf_bridge_count = 0
non_leaf_bridge_count = 0

for u, v in bridges:
    if (G_undirected.degree[u] == 1 or G_undirected.degree[v] == 1):
        leaf_bridge_count += 1
    else:
        non_leaf_bridge_count += 1

print("Leaf-related bridges:", leaf_bridge_count)
print("Non-leaf bridges:", non_leaf_bridge_count)
# Out:
# Leaf-related bridges: 716
# Non-leaf bridges: 41
